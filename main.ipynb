# %%
import gymnasium as gym
from gymnasium.wrappers import RecordVideo
import tensorflow as tf
import numpy as np
print(tf.__version__)
print(np.__version__)
print(gym.__version__)
# Out:
# 2.10.0
# 1.23.5
# 0.29.1

# %%
eval_env = gym.make("LunarLander-v2", render_mode="rgb_array")

eval_env = RecordVideo(
    eval_env,
    video_folder="videos",
    name_prefix="dqn_lander",
    episode_trigger=lambda ep_id: True
)
# Out:
# c:\Users\hp\Documents\tf_gpu\tf2-gpu\lib\site-packages\gymnasium\wrappers\record_video.py:94: UserWarning: WARN: Overwriting existing videos at c:\Users\hp\Documents\tf_gpu\rl_rev\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
env=gym.make("LunarLander-v2")
state,info=env.reset()
print("State shape:", state.shape)
print("""Example state: \n lander-x-position  lander-y-position  x-velocity  y-velocity  lander-angle  angular-velocity  left-leg-contact (0/1)  right-leg-contact (0/1) \n""", state)
print(info)
# Out:
# State shape: (8,)
# Example state:
#  lander-x-position  lander-y-position  x-velocity  y-velocity  lander-angle  angular-velocity  left-leg-contact (0/1)  right-leg-contact (0/1)
#  [-8.2015991e-05  1.4073536e+00 -8.3260518e-03 -1.5850526e-01
#   1.0186795e-04  1.8859804e-03  0.0000000e+00  0.0000000e+00]
# {}

# %%
state, info = env.reset()
done = False
total_reward = 0.0
action = env.action_space.sample()
next_state, reward, terminated, truncated, info = env.step(action)
done = terminated or truncated
total_reward += reward
print("Initial state : \n", state)
print("Action take: ",action)
print("reward: ",reward)
print("new state: \n", next_state)
print("finished : ",done)
state = next_state
# Out:
# Initial state :
#  [-0.00319138  1.4151587  -0.32326803  0.18838756  0.00370481  0.07322507
#   0.          0.        ]
# Action take:  2
# reward:  -2.606218559542344
# new state:
#  [-0.00649061  1.4197048  -0.333062    0.20203356  0.00681665  0.06224305
#   0.          0.        ]
# finished :  False

# %% [markdown]
# ## Value: even if the current reward is 0, how good can the future reward be??? more formally how good is the future given the current state and policy that we will follow to choose further actions

# %% [markdown]
# ## Q-Value : sometimes just knowing value of a state isnt enoguh,
# ### Q(s, a) = expected future total reward if action a is taken in state s, then follow current policy.
# Why Q-values are great?
#
# Because best action is simple:
#
# best action = max( q(s,all possible actions))

# %%
from collections import deque
import random


# cur_state, action,reward, next state, done?
class ReplayBuffer:
    def __init__(self,max_size,state_dim):
        self.max_size=max_size
        self.state_dim=state_dim
        self.memory=deque(maxlen=max_size)
    def add (self,state,action,reward,next_state,done):
        self.memory.append((state,action,reward, next_state,done))

    def sample(self,batch_size):
        batch=random.sample(self.memory,batch_size)
        states,actions,rewards,next_states,dones=zip(*batch)

        states=np.array(states,dtype=np.float32)
        actions=np.array(actions,dtype=np.int32)
        rewards=np.array(rewards,dtype=np.float32)
        next_states=np.array(next_states,dtype=np.float32)
        dones=np.array(dones,dtype=np.float32)

        return states,actions,rewards,next_states,dones
    
    def __len__(self):
        return len(self.memory)

# %%
def create_neural_network(state_dim,action_dim):
    model=tf.keras.Sequential([
        tf.keras.layers.Dense(64,activation='relu',input_dim=state_dim),
        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.Dense(action_dim)
    ])
    return model

state_dim=8
action_dim=4

q_network=create_neural_network(state_dim,action_dim)
target_q_network=create_neural_network(state_dim,action_dim)

target_q_network.set_weights(q_network.get_weights())

# %%
def select_action(state,epsilon):
    if np.random.rand()<epsilon:
        return env.action_space.sample()
    else:
        state_tensor = tf.convert_to_tensor(state[None, :], dtype=tf.float32)
        q_values = q_network(state_tensor)
        action = tf.argmax(q_values[0]).numpy()
        return int(action)

# %%
def run_eval_episode(eval_env, epsilon_eval=0.00):
    state, info = eval_env.reset()
    done = False
    total_reward = 0.0

    while not done:
        if np.random.rand() < epsilon_eval:
            action = eval_env.action_space.sample()
        else:
            state_tensor = tf.convert_to_tensor(state[None, :], dtype=tf.float32)
            q_values = q_network(state_tensor)
            action = int(tf.argmax(q_values[0]).numpy())
        next_state, reward, terminated, truncated, info = eval_env.step(action)
        done = terminated or truncated

        total_reward += reward
        state = next_state

    return total_reward

# %%
def update_target_network():
    target_q_network.set_weights(q_network.get_weights())

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
gamma = 0.99

@tf.function
def train_step(states, actions, rewards, next_states, dones):

    next_q_values = target_q_network(next_states)
    max_next_q = tf.reduce_max(next_q_values, axis=1)
    target_q = rewards + gamma * (1.0 - dones) * max_next_q

    with tf.GradientTape() as tape:
        all_q = q_network(states)
        batch_indices = tf.range(tf.shape(actions)[0], dtype=tf.int32)
        indices = tf.stack([batch_indices, actions], axis=1)
        chosen_q = tf.gather_nd(all_q, indices)
        loss = tf.reduce_mean(tf.square(target_q - chosen_q))
    grads = tape.gradient(loss, q_network.trainable_variables)
    optimizer.apply_gradients(zip(grads, q_network.trainable_variables))

    return loss

# %%
num_episodes = 500
eval_interval=50
batch_size = 64

epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.995

target_update_freq = 1000
max_steps_per_episode = 1000

total_steps = 0
eval_rewards=[]

buffer = ReplayBuffer(max_size=100_000, state_dim=8)
for episode in range(num_episodes):
    state, info = env.reset()
    episode_reward = 0.0
    done = False

    for t in range(max_steps_per_episode):
        action = select_action(state, epsilon)
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        buffer.add(state, action, reward, next_state, float(done))

        state = next_state
        episode_reward += reward
        total_steps += 1
        if len(buffer) >= batch_size:
            states, actions, rewards, next_states, dones = buffer.sample(batch_size)
            loss = train_step(states, actions, rewards, next_states, dones)
        else:
            loss = None

        if total_steps % target_update_freq == 0:
            update_target_network()

        if done:
            break
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay
        epsilon = max(epsilon, epsilon_min)

    if loss is not None:
        print(f"Episode {episode} | Reward: {episode_reward:.2f} | Epsilon: {epsilon:.3f} | Loss: {loss:.4f}")
    else:
        print(f"Episode {episode} | Reward: {episode_reward:.2f} | Epsilon: {epsilon:.3f} | Loss: N/A (buffer warming)")
    if (episode + 1) % eval_interval == 0:
        eval_reward = run_eval_episode(eval_env, epsilon_eval=0.05)
        eval_rewards.append(eval_reward)
        print(f"[EVAL] Episode {episode + 1} | Eval reward: {eval_reward:.2f} (video saved)")
# Out:
# Episode 0 | Reward: -81.50 | Epsilon: 0.995 | Loss: 161.5722
# Episode 1 | Reward: -86.25 | Epsilon: 0.990 | Loss: 123.4518
# Episode 2 | Reward: -139.89 | Epsilon: 0.985 | Loss: 179.5378
# Episode 3 | Reward: -391.50 | Epsilon: 0.980 | Loss: 15.4249
# Episode 4 | Reward: -109.10 | Epsilon: 0.975 | Loss: 149.8950
# Episode 5 | Reward: -166.17 | Epsilon: 0.970 | Loss: 257.6624
# Episode 6 | Reward: -304.76 | Epsilon: 0.966 | Loss: 18.1936
# Episode 7 | Reward: -166.46 | Epsilon: 0.961 | Loss: 79.9845
# Episode 8 | Reward: -101.26 | Epsilon: 0.956 | Loss: 106.1237
# Episode 9 | Reward: -110.95 | Epsilon: 0.951 | Loss: 10.6018
# Episode 10 | Reward: -474.61 | Epsilon: 0.946 | Loss: 6.7218
# Episode 11 | Reward: -140.45 | Epsilon: 0.942 | Loss: 23.3369
# Episode 12 | Reward: -269.58 | Epsilon: 0.937 | Loss: 149.6623
# Episode 13 | Reward: -121.64 | Epsilon: 0.932 | Loss: 200.5397
# Episode 14 | Reward: -95.35 | Epsilon: 0.928 | Loss: 5.1047
# Episode 15 | Reward: -243.21 | Epsilon: 0.923 | Loss: 38.5859
# Episode 16 | Reward: -75.80 | Epsilon: 0.918 | Loss: 9.1582
# Episode 17 | Reward: -98.82 | Epsilon: 0.914 | Loss: 42.3817
# Episode 18 | Reward: -97.36 | Epsilon: 0.909 | Loss: 106.9952
# Episode 19 | Reward: -138.16 | Epsilon: 0.905 | Loss: 4.5281
# Episode 20 | Reward: -91.11 | Epsilon: 0.900 | Loss: 2.3706
# Episode 21 | Reward: -437.72 | Epsilon: 0.896 | Loss: 151.5696
# Episode 22 | Reward: -117.78 | Epsilon: 0.891 | Loss: 116.8621
# Episode 23 | Reward: -321.75 | Epsilon: 0.887 | Loss: 11.3762
# Episode 24 | Reward: -94.01 | Epsilon: 0.882 | Loss: 3.3727
# Episode 25 | Reward: -96.33 | Epsilon: 0.878 | Loss: 62.1105
# Episode 26 | Reward: -127.79 | Epsilon: 0.873 | Loss: 26.9665
# Episode 27 | Reward: -94.67 | Epsilon: 0.869 | Loss: 18.4985
# Episode 28 | Reward: -89.94 | Epsilon: 0.865 | Loss: 62.3361
# Episode 29 | Reward: -105.16 | Epsilon: 0.860 | Loss: 9.8451
# Episode 30 | Reward: -92.15 | Epsilon: 0.856 | Loss: 102.6632
# Episode 31 | Reward: -117.70 | Epsilon: 0.852 | Loss: 18.5306
# Episode 32 | Reward: -71.79 | Epsilon: 0.848 | Loss: 38.0509
# Episode 33 | Reward: -91.72 | Epsilon: 0.843 | Loss: 105.0430
# Episode 34 | Reward: -200.55 | Epsilon: 0.839 | Loss: 35.6967
# Episode 35 | Reward: -80.51 | Epsilon: 0.835 | Loss: 4.2555
# Episode 36 | Reward: -125.61 | Epsilon: 0.831 | Loss: 56.3296
# Episode 37 | Reward: -71.45 | Epsilon: 0.827 | Loss: 12.3474
# Episode 38 | Reward: -104.49 | Epsilon: 0.822 | Loss: 1.0820
# Episode 39 | Reward: -87.14 | Epsilon: 0.818 | Loss: 3.4683
# Episode 40 | Reward: -107.28 | Epsilon: 0.814 | Loss: 71.0308
# Episode 41 | Reward: -205.65 | Epsilon: 0.810 | Loss: 6.0999
# Episode 42 | Reward: -64.78 | Epsilon: 0.806 | Loss: 16.1367
# Episode 43 | Reward: -103.72 | Epsilon: 0.802 | Loss: 57.0462
# Episode 44 | Reward: -134.64 | Epsilon: 0.798 | Loss: 1.0298
# Episode 45 | Reward: -160.32 | Epsilon: 0.794 | Loss: 7.2552
# Episode 46 | Reward: -81.96 | Epsilon: 0.790 | Loss: 32.8094
# Episode 47 | Reward: -66.26 | Epsilon: 0.786 | Loss: 34.5434
# Episode 48 | Reward: -65.93 | Epsilon: 0.782 | Loss: 12.8183
# Episode 49 | Reward: -18.16 | Epsilon: 0.778 | Loss: 1.9798
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-0.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-0.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-0.mp4
# [EVAL] Episode 50 | Eval reward: -228.88 (video saved)
# Episode 50 | Reward: -90.86 | Epsilon: 0.774 | Loss: 16.2148
# Episode 51 | Reward: -122.66 | Epsilon: 0.771 | Loss: 37.9615
# Episode 52 | Reward: -275.44 | Epsilon: 0.767 | Loss: 5.3174
# Episode 53 | Reward: -172.05 | Epsilon: 0.763 | Loss: 1.6016
# Episode 54 | Reward: -58.09 | Epsilon: 0.759 | Loss: 1.1188
# Episode 55 | Reward: -153.81 | Epsilon: 0.755 | Loss: 7.0894
# Episode 56 | Reward: -92.64 | Epsilon: 0.751 | Loss: 50.7046
# Episode 57 | Reward: -69.09 | Epsilon: 0.748 | Loss: 3.7825
# Episode 58 | Reward: -52.19 | Epsilon: 0.744 | Loss: 18.9298
# Episode 59 | Reward: -94.46 | Epsilon: 0.740 | Loss: 1.6457
# Episode 60 | Reward: -86.94 | Epsilon: 0.737 | Loss: 27.0814
# Episode 61 | Reward: -67.84 | Epsilon: 0.733 | Loss: 19.7442
# Episode 62 | Reward: -94.45 | Epsilon: 0.729 | Loss: 2.3762
# Episode 63 | Reward: -96.18 | Epsilon: 0.726 | Loss: 2.0405
# Episode 64 | Reward: -40.53 | Epsilon: 0.722 | Loss: 42.2696
# Episode 65 | Reward: -85.66 | Epsilon: 0.718 | Loss: 39.7749
# Episode 66 | Reward: -68.07 | Epsilon: 0.715 | Loss: 11.1608
# Episode 67 | Reward: -93.25 | Epsilon: 0.711 | Loss: 1.2591
# Episode 68 | Reward: -99.76 | Epsilon: 0.708 | Loss: 14.4803
# Episode 69 | Reward: -107.33 | Epsilon: 0.704 | Loss: 13.7317
# Episode 70 | Reward: -78.57 | Epsilon: 0.701 | Loss: 15.7743
# Episode 71 | Reward: -135.82 | Epsilon: 0.697 | Loss: 4.3167
# Episode 72 | Reward: -109.82 | Epsilon: 0.694 | Loss: 1.7749
# Episode 73 | Reward: -57.85 | Epsilon: 0.690 | Loss: 2.8163
# Episode 74 | Reward: -244.80 | Epsilon: 0.687 | Loss: 1.2886
# Episode 75 | Reward: -100.93 | Epsilon: 0.683 | Loss: 3.3067
# Episode 76 | Reward: -79.99 | Epsilon: 0.680 | Loss: 11.4203
# Episode 77 | Reward: -18.03 | Epsilon: 0.676 | Loss: 2.2278
# Episode 78 | Reward: -37.29 | Epsilon: 0.673 | Loss: 4.1316
# Episode 79 | Reward: -73.77 | Epsilon: 0.670 | Loss: 3.3044
# Episode 80 | Reward: -109.73 | Epsilon: 0.666 | Loss: 21.9648
# Episode 81 | Reward: -51.22 | Epsilon: 0.663 | Loss: 22.9223
# Episode 82 | Reward: -61.68 | Epsilon: 0.660 | Loss: 1.4769
# Episode 83 | Reward: -75.92 | Epsilon: 0.656 | Loss: 6.8639
# Episode 84 | Reward: -275.97 | Epsilon: 0.653 | Loss: 26.3059
# Episode 85 | Reward: -128.83 | Epsilon: 0.650 | Loss: 45.8805
# Episode 86 | Reward: -110.58 | Epsilon: 0.647 | Loss: 10.1079
# Episode 87 | Reward: -146.58 | Epsilon: 0.643 | Loss: 10.8042
# Episode 88 | Reward: -168.97 | Epsilon: 0.640 | Loss: 15.6141
# Episode 89 | Reward: -251.17 | Epsilon: 0.637 | Loss: 26.5341
# Episode 90 | Reward: -7.22 | Epsilon: 0.634 | Loss: 1.1902
# Episode 91 | Reward: -32.76 | Epsilon: 0.631 | Loss: 23.3931
# Episode 92 | Reward: -61.21 | Epsilon: 0.627 | Loss: 18.9356
# Episode 93 | Reward: -21.17 | Epsilon: 0.624 | Loss: 7.8549
# Episode 94 | Reward: -83.84 | Epsilon: 0.621 | Loss: 1.2305
# Episode 95 | Reward: -65.61 | Epsilon: 0.618 | Loss: 3.1896
# Episode 96 | Reward: -50.33 | Epsilon: 0.615 | Loss: 2.0356
# Episode 97 | Reward: -168.88 | Epsilon: 0.612 | Loss: 1.0094
# Episode 98 | Reward: -56.16 | Epsilon: 0.609 | Loss: 21.0140
# Episode 99 | Reward: -13.02 | Epsilon: 0.606 | Loss: 13.5781
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-1.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-1.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-1.mp4
# [EVAL] Episode 100 | Eval reward: -172.25 (video saved)
# Episode 100 | Reward: -86.14 | Epsilon: 0.603 | Loss: 8.8303
# Episode 101 | Reward: -65.34 | Epsilon: 0.600 | Loss: 1.5345
# Episode 102 | Reward: -36.14 | Epsilon: 0.597 | Loss: 18.7611
# Episode 103 | Reward: -1.31 | Epsilon: 0.594 | Loss: 2.4431
# Episode 104 | Reward: -34.91 | Epsilon: 0.591 | Loss: 20.0691
# Episode 105 | Reward: -43.23 | Epsilon: 0.588 | Loss: 24.0197
# Episode 106 | Reward: -37.51 | Epsilon: 0.585 | Loss: 1.6436
# Episode 107 | Reward: -60.54 | Epsilon: 0.582 | Loss: 81.1465
# Episode 108 | Reward: -63.86 | Epsilon: 0.579 | Loss: 4.0413
# Episode 109 | Reward: -70.35 | Epsilon: 0.576 | Loss: 17.0482
# Episode 110 | Reward: -54.68 | Epsilon: 0.573 | Loss: 3.5820
# Episode 111 | Reward: -121.32 | Epsilon: 0.570 | Loss: 1.3338
# Episode 112 | Reward: -82.01 | Epsilon: 0.568 | Loss: 8.2387
# Episode 113 | Reward: -29.78 | Epsilon: 0.565 | Loss: 6.2209
# Episode 114 | Reward: -40.96 | Epsilon: 0.562 | Loss: 6.4897
# Episode 115 | Reward: -34.08 | Epsilon: 0.559 | Loss: 12.0591
# Episode 116 | Reward: -26.53 | Epsilon: 0.556 | Loss: 21.5899
# Episode 117 | Reward: -66.65 | Epsilon: 0.554 | Loss: 3.2852
# Episode 118 | Reward: -58.22 | Epsilon: 0.551 | Loss: 36.5346
# Episode 119 | Reward: -38.73 | Epsilon: 0.548 | Loss: 2.8378
# Episode 120 | Reward: -191.17 | Epsilon: 0.545 | Loss: 7.7707
# Episode 121 | Reward: -46.27 | Epsilon: 0.543 | Loss: 30.7519
# Episode 122 | Reward: -325.75 | Epsilon: 0.540 | Loss: 100.2596
# Episode 123 | Reward: -72.67 | Epsilon: 0.537 | Loss: 20.3133
# Episode 124 | Reward: -68.40 | Epsilon: 0.534 | Loss: 6.8416
# Episode 125 | Reward: -242.94 | Epsilon: 0.532 | Loss: 2.1781
# Episode 126 | Reward: -103.47 | Epsilon: 0.529 | Loss: 1.2169
# Episode 127 | Reward: -6.16 | Epsilon: 0.526 | Loss: 1.9258
# Episode 128 | Reward: -46.45 | Epsilon: 0.524 | Loss: 0.9899
# Episode 129 | Reward: -42.69 | Epsilon: 0.521 | Loss: 8.3008
# Episode 130 | Reward: -41.02 | Epsilon: 0.519 | Loss: 3.9826
# Episode 131 | Reward: -354.03 | Epsilon: 0.516 | Loss: 2.9093
# Episode 132 | Reward: -67.77 | Epsilon: 0.513 | Loss: 5.1582
# Episode 133 | Reward: -184.28 | Epsilon: 0.511 | Loss: 6.3479
# Episode 134 | Reward: -36.94 | Epsilon: 0.508 | Loss: 4.1379
# Episode 135 | Reward: -23.65 | Epsilon: 0.506 | Loss: 5.0753
# Episode 136 | Reward: -56.88 | Epsilon: 0.503 | Loss: 3.6804
# Episode 137 | Reward: -69.33 | Epsilon: 0.501 | Loss: 1.7760
# Episode 138 | Reward: -203.61 | Epsilon: 0.498 | Loss: 12.5466
# Episode 139 | Reward: -146.48 | Epsilon: 0.496 | Loss: 3.1039
# Episode 140 | Reward: -8.02 | Epsilon: 0.493 | Loss: 8.5272
# Episode 141 | Reward: 13.98 | Epsilon: 0.491 | Loss: 21.1461
# Episode 142 | Reward: -10.51 | Epsilon: 0.488 | Loss: 2.6605
# Episode 143 | Reward: -2.87 | Epsilon: 0.486 | Loss: 4.3887
# Episode 144 | Reward: -73.62 | Epsilon: 0.483 | Loss: 162.5372
# Episode 145 | Reward: -180.16 | Epsilon: 0.481 | Loss: 4.4381
# Episode 146 | Reward: -9.08 | Epsilon: 0.479 | Loss: 3.3608
# Episode 147 | Reward: -37.80 | Epsilon: 0.476 | Loss: 10.7728
# Episode 148 | Reward: -88.01 | Epsilon: 0.474 | Loss: 1.0609
# Episode 149 | Reward: -76.64 | Epsilon: 0.471 | Loss: 5.5916
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-2.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-2.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-2.mp4
# [EVAL] Episode 150 | Eval reward: -192.67 (video saved)
# Episode 150 | Reward: -31.98 | Epsilon: 0.469 | Loss: 13.1516
# Episode 151 | Reward: -83.21 | Epsilon: 0.467 | Loss: 7.1914
# Episode 152 | Reward: -0.64 | Epsilon: 0.464 | Loss: 2.1572
# Episode 153 | Reward: -7.27 | Epsilon: 0.462 | Loss: 10.2138
# Episode 154 | Reward: -23.37 | Epsilon: 0.460 | Loss: 11.0302
# Episode 155 | Reward: 19.65 | Epsilon: 0.458 | Loss: 74.1220
# Episode 156 | Reward: -278.13 | Epsilon: 0.455 | Loss: 9.3705
# Episode 157 | Reward: -11.22 | Epsilon: 0.453 | Loss: 1.2156
# Episode 158 | Reward: -53.24 | Epsilon: 0.451 | Loss: 1.7793
# Episode 159 | Reward: -23.82 | Epsilon: 0.448 | Loss: 14.2870
# Episode 160 | Reward: -0.12 | Epsilon: 0.446 | Loss: 2.4515
# Episode 161 | Reward: -352.99 | Epsilon: 0.444 | Loss: 7.2141
# Episode 162 | Reward: -30.91 | Epsilon: 0.442 | Loss: 29.0596
# Episode 163 | Reward: -493.33 | Epsilon: 0.440 | Loss: 1.8770
# Episode 164 | Reward: 53.89 | Epsilon: 0.437 | Loss: 3.9652
# Episode 165 | Reward: -129.21 | Epsilon: 0.435 | Loss: 13.2282
# Episode 166 | Reward: -23.11 | Epsilon: 0.433 | Loss: 24.6212
# Episode 167 | Reward: -65.76 | Epsilon: 0.431 | Loss: 18.5774
# Episode 168 | Reward: -41.93 | Epsilon: 0.429 | Loss: 6.4926
# Episode 169 | Reward: -216.84 | Epsilon: 0.427 | Loss: 7.3217
# Episode 170 | Reward: -38.23 | Epsilon: 0.424 | Loss: 12.5995
# Episode 171 | Reward: -18.48 | Epsilon: 0.422 | Loss: 6.6256
# Episode 172 | Reward: -20.02 | Epsilon: 0.420 | Loss: 4.0575
# Episode 173 | Reward: -87.81 | Epsilon: 0.418 | Loss: 6.4356
# Episode 174 | Reward: -56.69 | Epsilon: 0.416 | Loss: 45.2128
# Episode 175 | Reward: -189.77 | Epsilon: 0.414 | Loss: 1.9430
# Episode 176 | Reward: -37.62 | Epsilon: 0.412 | Loss: 42.6463
# Episode 177 | Reward: -8.25 | Epsilon: 0.410 | Loss: 10.7244
# Episode 178 | Reward: -42.49 | Epsilon: 0.408 | Loss: 4.6525
# Episode 179 | Reward: -75.50 | Epsilon: 0.406 | Loss: 13.4748
# Episode 180 | Reward: -64.56 | Epsilon: 0.404 | Loss: 15.2655
# Episode 181 | Reward: -327.14 | Epsilon: 0.402 | Loss: 6.0116
# Episode 182 | Reward: -28.60 | Epsilon: 0.400 | Loss: 10.7628
# Episode 183 | Reward: 20.91 | Epsilon: 0.398 | Loss: 16.5019
# Episode 184 | Reward: -219.29 | Epsilon: 0.396 | Loss: 2.1764
# Episode 185 | Reward: 21.05 | Epsilon: 0.394 | Loss: 49.4057
# Episode 186 | Reward: -292.22 | Epsilon: 0.392 | Loss: 4.1420
# Episode 187 | Reward: -25.93 | Epsilon: 0.390 | Loss: 13.1121
# Episode 188 | Reward: -125.41 | Epsilon: 0.388 | Loss: 2.6412
# Episode 189 | Reward: -53.53 | Epsilon: 0.386 | Loss: 59.2799
# Episode 190 | Reward: 19.62 | Epsilon: 0.384 | Loss: 6.8072
# Episode 191 | Reward: -20.86 | Epsilon: 0.382 | Loss: 4.8835
# Episode 192 | Reward: -54.23 | Epsilon: 0.380 | Loss: 13.1115
# Episode 193 | Reward: -89.07 | Epsilon: 0.378 | Loss: 7.4207
# Episode 194 | Reward: -15.21 | Epsilon: 0.376 | Loss: 25.2779
# Episode 195 | Reward: -80.25 | Epsilon: 0.374 | Loss: 4.3893
# Episode 196 | Reward: 1.13 | Epsilon: 0.373 | Loss: 108.7656
# Episode 197 | Reward: -50.40 | Epsilon: 0.371 | Loss: 75.6396
# Episode 198 | Reward: -55.71 | Epsilon: 0.369 | Loss: 2.3302
# Episode 199 | Reward: -141.97 | Epsilon: 0.367 | Loss: 8.2961
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-3.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-3.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-3.mp4
# [EVAL] Episode 200 | Eval reward: -187.14 (video saved)
# Episode 200 | Reward: -26.48 | Epsilon: 0.365 | Loss: 2.3645
# Episode 201 | Reward: -1.58 | Epsilon: 0.363 | Loss: 10.4835
# Episode 202 | Reward: -35.97 | Epsilon: 0.361 | Loss: 3.6910
# Episode 203 | Reward: -217.75 | Epsilon: 0.360 | Loss: 6.3180
# Episode 204 | Reward: -81.06 | Epsilon: 0.358 | Loss: 9.0419
# Episode 205 | Reward: -70.87 | Epsilon: 0.356 | Loss: 7.3839
# Episode 206 | Reward: -47.83 | Epsilon: 0.354 | Loss: 16.0178
# Episode 207 | Reward: 5.56 | Epsilon: 0.353 | Loss: 4.4203
# Episode 208 | Reward: 20.93 | Epsilon: 0.351 | Loss: 25.5949
# Episode 209 | Reward: -185.99 | Epsilon: 0.349 | Loss: 12.9732
# Episode 210 | Reward: -24.80 | Epsilon: 0.347 | Loss: 8.2924
# Episode 211 | Reward: -37.33 | Epsilon: 0.346 | Loss: 3.1501
# Episode 212 | Reward: -135.53 | Epsilon: 0.344 | Loss: 2.7654
# Episode 213 | Reward: -190.26 | Epsilon: 0.342 | Loss: 6.4346
# Episode 214 | Reward: -121.33 | Epsilon: 0.340 | Loss: 6.4643
# Episode 215 | Reward: -150.89 | Epsilon: 0.339 | Loss: 1.8197
# Episode 216 | Reward: -10.96 | Epsilon: 0.337 | Loss: 3.7730
# Episode 217 | Reward: -126.76 | Epsilon: 0.335 | Loss: 4.7567
# Episode 218 | Reward: -39.61 | Epsilon: 0.334 | Loss: 2.9231
# Episode 219 | Reward: -42.10 | Epsilon: 0.332 | Loss: 1.6716
# Episode 220 | Reward: -10.78 | Epsilon: 0.330 | Loss: 5.9722
# Episode 221 | Reward: -22.14 | Epsilon: 0.329 | Loss: 12.7161
# Episode 222 | Reward: -46.72 | Epsilon: 0.327 | Loss: 26.4359
# Episode 223 | Reward: -13.17 | Epsilon: 0.325 | Loss: 2.5423
# Episode 224 | Reward: -21.22 | Epsilon: 0.324 | Loss: 26.4466
# Episode 225 | Reward: 12.31 | Epsilon: 0.322 | Loss: 2.7636
# Episode 226 | Reward: -35.74 | Epsilon: 0.321 | Loss: 4.8981
# Episode 227 | Reward: -47.63 | Epsilon: 0.319 | Loss: 9.7449
# Episode 228 | Reward: -231.78 | Epsilon: 0.317 | Loss: 4.2338
# Episode 229 | Reward: -64.72 | Epsilon: 0.316 | Loss: 11.1872
# Episode 230 | Reward: 12.82 | Epsilon: 0.314 | Loss: 3.4462
# Episode 231 | Reward: -68.04 | Epsilon: 0.313 | Loss: 28.9587
# Episode 232 | Reward: -210.02 | Epsilon: 0.311 | Loss: 9.0456
# Episode 233 | Reward: -110.12 | Epsilon: 0.309 | Loss: 10.2042
# Episode 234 | Reward: -203.80 | Epsilon: 0.308 | Loss: 3.7865
# Episode 235 | Reward: -2.69 | Epsilon: 0.306 | Loss: 3.4678
# Episode 236 | Reward: -132.50 | Epsilon: 0.305 | Loss: 5.5971
# Episode 237 | Reward: -19.79 | Epsilon: 0.303 | Loss: 6.4326
# Episode 238 | Reward: -74.30 | Epsilon: 0.302 | Loss: 3.9694
# Episode 239 | Reward: -204.90 | Epsilon: 0.300 | Loss: 10.6235
# Episode 240 | Reward: -60.06 | Epsilon: 0.299 | Loss: 52.9305
# Episode 241 | Reward: -10.51 | Epsilon: 0.297 | Loss: 5.1168
# Episode 242 | Reward: -86.37 | Epsilon: 0.296 | Loss: 2.8828
# Episode 243 | Reward: -146.47 | Epsilon: 0.294 | Loss: 3.3050
# Episode 244 | Reward: 16.64 | Epsilon: 0.293 | Loss: 21.9257
# Episode 245 | Reward: -31.91 | Epsilon: 0.291 | Loss: 5.7180
# Episode 246 | Reward: -108.25 | Epsilon: 0.290 | Loss: 32.4879
# Episode 247 | Reward: -27.08 | Epsilon: 0.288 | Loss: 2.5840
# Episode 248 | Reward: -27.97 | Epsilon: 0.287 | Loss: 54.2344
# Episode 249 | Reward: -43.78 | Epsilon: 0.286 | Loss: 7.1274
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-4.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-4.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-4.mp4
# [EVAL] Episode 250 | Eval reward: -46.41 (video saved)
# Episode 250 | Reward: -42.90 | Epsilon: 0.284 | Loss: 21.7129
# Episode 251 | Reward: -37.01 | Epsilon: 0.283 | Loss: 11.9012
# Episode 252 | Reward: -42.16 | Epsilon: 0.281 | Loss: 5.9068
# Episode 253 | Reward: 22.23 | Epsilon: 0.280 | Loss: 12.0365
# Episode 254 | Reward: -44.81 | Epsilon: 0.279 | Loss: 3.1618
# Episode 255 | Reward: -35.23 | Epsilon: 0.277 | Loss: 2.5025
# Episode 256 | Reward: -54.97 | Epsilon: 0.276 | Loss: 2.7935
# Episode 257 | Reward: 53.75 | Epsilon: 0.274 | Loss: 5.2760
# Episode 258 | Reward: -23.59 | Epsilon: 0.273 | Loss: 3.9807
# Episode 259 | Reward: -0.16 | Epsilon: 0.272 | Loss: 7.7497
# Episode 260 | Reward: 55.16 | Epsilon: 0.270 | Loss: 2.1197
# Episode 261 | Reward: 17.22 | Epsilon: 0.269 | Loss: 2.9990
# Episode 262 | Reward: -23.96 | Epsilon: 0.268 | Loss: 18.5631
# Episode 263 | Reward: -7.19 | Epsilon: 0.266 | Loss: 5.4424
# Episode 264 | Reward: -16.62 | Epsilon: 0.265 | Loss: 2.9355
# Episode 265 | Reward: 9.06 | Epsilon: 0.264 | Loss: 10.4576
# Episode 266 | Reward: -5.71 | Epsilon: 0.262 | Loss: 9.0128
# Episode 267 | Reward: -38.52 | Epsilon: 0.261 | Loss: 6.3858
# Episode 268 | Reward: -7.03 | Epsilon: 0.260 | Loss: 7.6972
# Episode 269 | Reward: 23.88 | Epsilon: 0.258 | Loss: 8.5482
# Episode 270 | Reward: 1.95 | Epsilon: 0.257 | Loss: 6.3964
# Episode 271 | Reward: 31.44 | Epsilon: 0.256 | Loss: 1.8455
# Episode 272 | Reward: 17.04 | Epsilon: 0.255 | Loss: 10.5149
# Episode 273 | Reward: -2.39 | Epsilon: 0.253 | Loss: 4.0394
# Episode 274 | Reward: -116.04 | Epsilon: 0.252 | Loss: 13.6273
# Episode 275 | Reward: 34.48 | Epsilon: 0.251 | Loss: 7.1713
# Episode 276 | Reward: 31.89 | Epsilon: 0.249 | Loss: 3.9964
# Episode 277 | Reward: 39.86 | Epsilon: 0.248 | Loss: 3.9902
# Episode 278 | Reward: -56.12 | Epsilon: 0.247 | Loss: 9.5499
# Episode 279 | Reward: -42.24 | Epsilon: 0.246 | Loss: 2.0617
# Episode 280 | Reward: -132.55 | Epsilon: 0.245 | Loss: 3.7872
# Episode 281 | Reward: 70.68 | Epsilon: 0.243 | Loss: 8.5726
# Episode 282 | Reward: 11.91 | Epsilon: 0.242 | Loss: 4.4738
# Episode 283 | Reward: 244.77 | Epsilon: 0.241 | Loss: 9.7241
# Episode 284 | Reward: 21.18 | Epsilon: 0.240 | Loss: 4.8494
# Episode 285 | Reward: 3.92 | Epsilon: 0.238 | Loss: 2.3529
# Episode 286 | Reward: 22.49 | Epsilon: 0.237 | Loss: 5.7501
# Episode 287 | Reward: 95.75 | Epsilon: 0.236 | Loss: 52.2911
# Episode 288 | Reward: 83.75 | Epsilon: 0.235 | Loss: 4.2832
# Episode 289 | Reward: 27.61 | Epsilon: 0.234 | Loss: 2.1403
# Episode 290 | Reward: 6.05 | Epsilon: 0.233 | Loss: 4.2235
# Episode 291 | Reward: -191.86 | Epsilon: 0.231 | Loss: 2.6490
# Episode 292 | Reward: 130.72 | Epsilon: 0.230 | Loss: 20.8170
# Episode 293 | Reward: 106.93 | Epsilon: 0.229 | Loss: 4.6557
# Episode 294 | Reward: 9.40 | Epsilon: 0.228 | Loss: 15.1120
# Episode 295 | Reward: 78.02 | Epsilon: 0.227 | Loss: 3.0760
# Episode 296 | Reward: -1.26 | Epsilon: 0.226 | Loss: 5.8590
# Episode 297 | Reward: 299.23 | Epsilon: 0.225 | Loss: 1.9075
# Episode 298 | Reward: 12.64 | Epsilon: 0.223 | Loss: 6.4296
# Episode 299 | Reward: 206.33 | Epsilon: 0.222 | Loss: 1.7833
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-5.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-5.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-5.mp4
# [EVAL] Episode 300 | Eval reward: 1.45 (video saved)
# Episode 300 | Reward: -3.71 | Epsilon: 0.221 | Loss: 1.8459
# Episode 301 | Reward: 75.09 | Epsilon: 0.220 | Loss: 9.4666
# Episode 302 | Reward: 190.94 | Epsilon: 0.219 | Loss: 1.7956
# Episode 303 | Reward: -47.37 | Epsilon: 0.218 | Loss: 2.3993
# Episode 304 | Reward: 156.65 | Epsilon: 0.217 | Loss: 3.4761
# Episode 305 | Reward: 61.46 | Epsilon: 0.216 | Loss: 9.4229
# Episode 306 | Reward: 48.67 | Epsilon: 0.215 | Loss: 12.6329
# Episode 307 | Reward: 87.80 | Epsilon: 0.214 | Loss: 49.5325
# Episode 308 | Reward: 161.95 | Epsilon: 0.212 | Loss: 8.0946
# Episode 309 | Reward: -212.51 | Epsilon: 0.211 | Loss: 7.0326
# Episode 310 | Reward: -3.28 | Epsilon: 0.210 | Loss: 3.7257
# Episode 311 | Reward: -42.57 | Epsilon: 0.209 | Loss: 4.7417
# Episode 312 | Reward: 239.70 | Epsilon: 0.208 | Loss: 4.2253
# Episode 313 | Reward: 206.36 | Epsilon: 0.207 | Loss: 11.3597
# Episode 314 | Reward: 18.03 | Epsilon: 0.206 | Loss: 7.1885
# Episode 315 | Reward: 294.60 | Epsilon: 0.205 | Loss: 10.1794
# Episode 316 | Reward: -397.29 | Epsilon: 0.204 | Loss: 3.6883
# Episode 317 | Reward: 110.02 | Epsilon: 0.203 | Loss: 15.9789
# Episode 318 | Reward: 152.29 | Epsilon: 0.202 | Loss: 19.9693
# Episode 319 | Reward: 92.14 | Epsilon: 0.201 | Loss: 6.4838
# Episode 320 | Reward: -161.78 | Epsilon: 0.200 | Loss: 50.2686
# Episode 321 | Reward: 90.84 | Epsilon: 0.199 | Loss: 4.7528
# Episode 322 | Reward: 90.28 | Epsilon: 0.198 | Loss: 1.9352
# Episode 323 | Reward: 135.37 | Epsilon: 0.197 | Loss: 2.4029
# Episode 324 | Reward: 13.36 | Epsilon: 0.196 | Loss: 4.9198
# Episode 325 | Reward: -12.21 | Epsilon: 0.195 | Loss: 89.2516
# Episode 326 | Reward: 257.60 | Epsilon: 0.194 | Loss: 3.8225
# Episode 327 | Reward: 141.70 | Epsilon: 0.193 | Loss: 9.7406
# Episode 328 | Reward: 200.63 | Epsilon: 0.192 | Loss: 3.4420
# Episode 329 | Reward: 105.21 | Epsilon: 0.191 | Loss: 5.0779
# Episode 330 | Reward: -209.12 | Epsilon: 0.190 | Loss: 2.0228
# Episode 331 | Reward: 246.18 | Epsilon: 0.189 | Loss: 5.1520
# Episode 332 | Reward: 141.19 | Epsilon: 0.188 | Loss: 1.6619
# Episode 333 | Reward: 191.05 | Epsilon: 0.187 | Loss: 157.3381
# Episode 334 | Reward: 56.80 | Epsilon: 0.187 | Loss: 2.7419
# Episode 335 | Reward: 91.99 | Epsilon: 0.186 | Loss: 2.6285
# Episode 336 | Reward: 136.27 | Epsilon: 0.185 | Loss: 2.3442
# Episode 337 | Reward: 135.77 | Epsilon: 0.184 | Loss: 3.4117
# Episode 338 | Reward: 160.17 | Epsilon: 0.183 | Loss: 3.7642
# Episode 339 | Reward: 52.81 | Epsilon: 0.182 | Loss: 1.8714
# Episode 340 | Reward: 225.99 | Epsilon: 0.181 | Loss: 29.4294
# Episode 341 | Reward: 175.31 | Epsilon: 0.180 | Loss: 4.8175
# Episode 342 | Reward: 149.89 | Epsilon: 0.179 | Loss: 2.7188
# Episode 343 | Reward: 255.94 | Epsilon: 0.178 | Loss: 3.6491
# Episode 344 | Reward: 124.10 | Epsilon: 0.177 | Loss: 2.0267
# Episode 345 | Reward: 137.51 | Epsilon: 0.177 | Loss: 6.9782
# Episode 346 | Reward: 227.78 | Epsilon: 0.176 | Loss: 2.0254
# Episode 347 | Reward: 164.76 | Epsilon: 0.175 | Loss: 1.2911
# Episode 348 | Reward: -356.78 | Epsilon: 0.174 | Loss: 3.3240
# Episode 349 | Reward: 135.24 | Epsilon: 0.173 | Loss: 1.9206
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-6.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-6.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-6.mp4
# [EVAL] Episode 350 | Eval reward: 211.66 (video saved)
# Episode 350 | Reward: 297.68 | Epsilon: 0.172 | Loss: 2.6662
# Episode 351 | Reward: 224.34 | Epsilon: 0.171 | Loss: 4.8984
# Episode 352 | Reward: 255.46 | Epsilon: 0.170 | Loss: 0.9092
# Episode 353 | Reward: 194.44 | Epsilon: 0.170 | Loss: 17.1663
# Episode 354 | Reward: 241.71 | Epsilon: 0.169 | Loss: 2.0458
# Episode 355 | Reward: 228.23 | Epsilon: 0.168 | Loss: 6.6949
# Episode 356 | Reward: 260.36 | Epsilon: 0.167 | Loss: 2.2194
# Episode 357 | Reward: 69.84 | Epsilon: 0.166 | Loss: 2.0118
# Episode 358 | Reward: -4.00 | Epsilon: 0.165 | Loss: 98.0864
# Episode 359 | Reward: -21.26 | Epsilon: 0.165 | Loss: 1.4988
# Episode 360 | Reward: 237.84 | Epsilon: 0.164 | Loss: 3.6646
# Episode 361 | Reward: 109.43 | Epsilon: 0.163 | Loss: 2.6557
# Episode 362 | Reward: 24.76 | Epsilon: 0.162 | Loss: 2.2933
# Episode 363 | Reward: -109.95 | Epsilon: 0.161 | Loss: 2.6899
# Episode 364 | Reward: 188.51 | Epsilon: 0.160 | Loss: 3.9446
# Episode 365 | Reward: 267.01 | Epsilon: 0.160 | Loss: 1.3932
# Episode 366 | Reward: 176.23 | Epsilon: 0.159 | Loss: 2.2208
# Episode 367 | Reward: 240.60 | Epsilon: 0.158 | Loss: 2.1014
# Episode 368 | Reward: 248.13 | Epsilon: 0.157 | Loss: 2.3690
# Episode 369 | Reward: 274.69 | Epsilon: 0.157 | Loss: 2.1114
# Episode 370 | Reward: 154.81 | Epsilon: 0.156 | Loss: 3.1847
# Episode 371 | Reward: 268.89 | Epsilon: 0.155 | Loss: 1.5247
# Episode 372 | Reward: 251.15 | Epsilon: 0.154 | Loss: 1.3109
# Episode 373 | Reward: 229.51 | Epsilon: 0.153 | Loss: 1.4927
# Episode 374 | Reward: 299.49 | Epsilon: 0.153 | Loss: 1.1928
# Episode 375 | Reward: 279.55 | Epsilon: 0.152 | Loss: 4.5358
# Episode 376 | Reward: -16.48 | Epsilon: 0.151 | Loss: 1.4134
# Episode 377 | Reward: 255.33 | Epsilon: 0.150 | Loss: 3.2255
# Episode 378 | Reward: 215.02 | Epsilon: 0.150 | Loss: 0.8448
# Episode 379 | Reward: 260.26 | Epsilon: 0.149 | Loss: 3.4188
# Episode 380 | Reward: 284.21 | Epsilon: 0.148 | Loss: 1.4821
# Episode 381 | Reward: 137.63 | Epsilon: 0.147 | Loss: 2.2967
# Episode 382 | Reward: 24.18 | Epsilon: 0.147 | Loss: 1.3845
# Episode 383 | Reward: 250.94 | Epsilon: 0.146 | Loss: 2.9933
# Episode 384 | Reward: 228.96 | Epsilon: 0.145 | Loss: 1.4010
# Episode 385 | Reward: 246.39 | Epsilon: 0.144 | Loss: 1.0561
# Episode 386 | Reward: 245.82 | Epsilon: 0.144 | Loss: 2.0143
# Episode 387 | Reward: 263.32 | Epsilon: 0.143 | Loss: 1.7762
# Episode 388 | Reward: 237.39 | Epsilon: 0.142 | Loss: 1.6604
# Episode 389 | Reward: 258.40 | Epsilon: 0.142 | Loss: 4.4301
# Episode 390 | Reward: 243.42 | Epsilon: 0.141 | Loss: 2.7569
# Episode 391 | Reward: 285.05 | Epsilon: 0.140 | Loss: 1.6781
# Episode 392 | Reward: 134.74 | Epsilon: 0.139 | Loss: 2.8236
# Episode 393 | Reward: 234.03 | Epsilon: 0.139 | Loss: 4.3559
# Episode 394 | Reward: 257.95 | Epsilon: 0.138 | Loss: 4.2671
# Episode 395 | Reward: 239.65 | Epsilon: 0.137 | Loss: 1.5753
# Episode 396 | Reward: 223.63 | Epsilon: 0.137 | Loss: 6.1072
# Episode 397 | Reward: 143.10 | Epsilon: 0.136 | Loss: 1.7991
# Episode 398 | Reward: 196.99 | Epsilon: 0.135 | Loss: 2.8807
# Episode 399 | Reward: 249.96 | Epsilon: 0.135 | Loss: 0.8082
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-7.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-7.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-7.mp4
# [EVAL] Episode 400 | Eval reward: 231.03 (video saved)
# Episode 400 | Reward: 285.04 | Epsilon: 0.134 | Loss: 263.7839
# Episode 401 | Reward: 228.19 | Epsilon: 0.133 | Loss: 1.2424
# Episode 402 | Reward: 270.99 | Epsilon: 0.133 | Loss: 2.6755
# Episode 403 | Reward: 286.04 | Epsilon: 0.132 | Loss: 1.9913
# Episode 404 | Reward: 238.95 | Epsilon: 0.131 | Loss: 3.4222
# Episode 405 | Reward: 268.52 | Epsilon: 0.131 | Loss: 2.3286
# Episode 406 | Reward: 245.02 | Epsilon: 0.130 | Loss: 13.6796
# Episode 407 | Reward: 252.38 | Epsilon: 0.129 | Loss: 1.1474
# Episode 408 | Reward: 185.92 | Epsilon: 0.129 | Loss: 2.0528
# Episode 409 | Reward: 259.38 | Epsilon: 0.128 | Loss: 5.0820
# Episode 410 | Reward: 287.88 | Epsilon: 0.127 | Loss: 2.5025
# Episode 411 | Reward: 268.89 | Epsilon: 0.127 | Loss: 0.7800
# Episode 412 | Reward: 235.96 | Epsilon: 0.126 | Loss: 3.8641
# Episode 413 | Reward: -50.17 | Epsilon: 0.126 | Loss: 1.8282
# Episode 414 | Reward: 264.65 | Epsilon: 0.125 | Loss: 2.1506
# Episode 415 | Reward: 255.09 | Epsilon: 0.124 | Loss: 1.8599
# Episode 416 | Reward: -1.62 | Epsilon: 0.124 | Loss: 2.1566
# Episode 417 | Reward: -14.39 | Epsilon: 0.123 | Loss: 3.1701
# Episode 418 | Reward: -105.12 | Epsilon: 0.122 | Loss: 119.9411
# Episode 419 | Reward: 221.94 | Epsilon: 0.122 | Loss: 2.0478
# Episode 420 | Reward: 273.93 | Epsilon: 0.121 | Loss: 1.4014
# Episode 421 | Reward: 71.61 | Epsilon: 0.121 | Loss: 2.0909
# Episode 422 | Reward: 244.92 | Epsilon: 0.120 | Loss: 114.9388
# Episode 423 | Reward: -115.88 | Epsilon: 0.119 | Loss: 1.1932
# Episode 424 | Reward: 240.53 | Epsilon: 0.119 | Loss: 1.5462
# Episode 425 | Reward: 272.36 | Epsilon: 0.118 | Loss: 2.7581
# Episode 426 | Reward: 176.27 | Epsilon: 0.118 | Loss: 1.9470
# Episode 427 | Reward: 210.48 | Epsilon: 0.117 | Loss: 1.0936
# Episode 428 | Reward: 264.91 | Epsilon: 0.116 | Loss: 3.3771
# Episode 429 | Reward: 232.00 | Epsilon: 0.116 | Loss: 1.0691
# Episode 430 | Reward: 235.17 | Epsilon: 0.115 | Loss: 1.7629
# Episode 431 | Reward: 245.89 | Epsilon: 0.115 | Loss: 3.5563
# Episode 432 | Reward: 243.94 | Epsilon: 0.114 | Loss: 2.6537
# Episode 433 | Reward: 252.38 | Epsilon: 0.114 | Loss: 1.9754
# Episode 434 | Reward: 293.53 | Epsilon: 0.113 | Loss: 3.9636
# Episode 435 | Reward: 233.44 | Epsilon: 0.112 | Loss: 0.3978
# Episode 436 | Reward: 164.58 | Epsilon: 0.112 | Loss: 0.7745
# Episode 437 | Reward: 228.26 | Epsilon: 0.111 | Loss: 1.6404
# Episode 438 | Reward: 185.14 | Epsilon: 0.111 | Loss: 11.8514
# Episode 439 | Reward: 244.90 | Epsilon: 0.110 | Loss: 1.5301
# Episode 440 | Reward: 253.38 | Epsilon: 0.110 | Loss: 1.1929
# Episode 441 | Reward: 222.68 | Epsilon: 0.109 | Loss: 6.2935
# Episode 442 | Reward: 254.14 | Epsilon: 0.109 | Loss: 8.3604
# Episode 443 | Reward: 242.35 | Epsilon: 0.108 | Loss: 3.4577
# Episode 444 | Reward: 254.85 | Epsilon: 0.107 | Loss: 6.5036
# Episode 445 | Reward: 256.35 | Epsilon: 0.107 | Loss: 0.9630
# Episode 446 | Reward: 126.00 | Epsilon: 0.106 | Loss: 2.2613
# Episode 447 | Reward: 281.49 | Epsilon: 0.106 | Loss: 1.2907
# Episode 448 | Reward: 243.71 | Epsilon: 0.105 | Loss: 3.8519
# Episode 449 | Reward: 271.61 | Epsilon: 0.105 | Loss: 0.6320
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-8.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-8.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-8.mp4
# [EVAL] Episode 450 | Eval reward: 258.57 (video saved)
# Episode 450 | Reward: 187.50 | Epsilon: 0.104 | Loss: 1.0394
# Episode 451 | Reward: 184.56 | Epsilon: 0.104 | Loss: 1.8472
# Episode 452 | Reward: 266.25 | Epsilon: 0.103 | Loss: 29.7632
# Episode 453 | Reward: 249.01 | Epsilon: 0.103 | Loss: 2.1121
# Episode 454 | Reward: -198.39 | Epsilon: 0.102 | Loss: 2.5302
# Episode 455 | Reward: 282.55 | Epsilon: 0.102 | Loss: 1.8449
# Episode 456 | Reward: 41.89 | Epsilon: 0.101 | Loss: 3.3463
# Episode 457 | Reward: 225.19 | Epsilon: 0.101 | Loss: 1.5778
# Episode 458 | Reward: 280.50 | Epsilon: 0.100 | Loss: 2.9231
# Episode 459 | Reward: -110.95 | Epsilon: 0.100 | Loss: 1.1553
# Episode 460 | Reward: 297.22 | Epsilon: 0.099 | Loss: 1.7538
# Episode 461 | Reward: 271.47 | Epsilon: 0.099 | Loss: 2.3366
# Episode 462 | Reward: 271.78 | Epsilon: 0.098 | Loss: 5.1636
# Episode 463 | Reward: 287.79 | Epsilon: 0.098 | Loss: 4.6900
# Episode 464 | Reward: 253.27 | Epsilon: 0.097 | Loss: 2.0822
# Episode 465 | Reward: 274.36 | Epsilon: 0.097 | Loss: 6.2829
# Episode 466 | Reward: 265.66 | Epsilon: 0.096 | Loss: 1.6760
# Episode 467 | Reward: 280.63 | Epsilon: 0.096 | Loss: 1.1183
# Episode 468 | Reward: 224.22 | Epsilon: 0.095 | Loss: 2.8521
# Episode 469 | Reward: 272.00 | Epsilon: 0.095 | Loss: 1.2913
# Episode 470 | Reward: 239.64 | Epsilon: 0.094 | Loss: 3.9897
# Episode 471 | Reward: -153.50 | Epsilon: 0.094 | Loss: 1.5202
# Episode 472 | Reward: 129.18 | Epsilon: 0.093 | Loss: 1.0345
# Episode 473 | Reward: 222.91 | Epsilon: 0.093 | Loss: 1.3709
# Episode 474 | Reward: 227.51 | Epsilon: 0.092 | Loss: 1.8235
# Episode 475 | Reward: 235.82 | Epsilon: 0.092 | Loss: 0.8066
# Episode 476 | Reward: 272.49 | Epsilon: 0.092 | Loss: 1.0534
# Episode 477 | Reward: 250.61 | Epsilon: 0.091 | Loss: 2.5167
# Episode 478 | Reward: 239.05 | Epsilon: 0.091 | Loss: 3.7756
# Episode 479 | Reward: 262.71 | Epsilon: 0.090 | Loss: 7.5784
# Episode 480 | Reward: 277.01 | Epsilon: 0.090 | Loss: 108.1712
# Episode 481 | Reward: 235.81 | Epsilon: 0.089 | Loss: 2.5904
# Episode 482 | Reward: 216.43 | Epsilon: 0.089 | Loss: 1.3020
# Episode 483 | Reward: 233.87 | Epsilon: 0.088 | Loss: 0.8438
# Episode 484 | Reward: 254.09 | Epsilon: 0.088 | Loss: 1.1599
# Episode 485 | Reward: 231.23 | Epsilon: 0.088 | Loss: 1.7354
# Episode 486 | Reward: 221.85 | Epsilon: 0.087 | Loss: 1.1987
# Episode 487 | Reward: 254.68 | Epsilon: 0.087 | Loss: 0.5704
# Episode 488 | Reward: -23.26 | Epsilon: 0.086 | Loss: 3.6296
# Episode 489 | Reward: 296.72 | Epsilon: 0.086 | Loss: 8.3206
# Episode 490 | Reward: 269.41 | Epsilon: 0.085 | Loss: 1.5164
# Episode 491 | Reward: 262.02 | Epsilon: 0.085 | Loss: 2.4927
# Episode 492 | Reward: 176.11 | Epsilon: 0.084 | Loss: 94.1531
# Episode 493 | Reward: 245.83 | Epsilon: 0.084 | Loss: 1.4157
# Episode 494 | Reward: 292.94 | Epsilon: 0.084 | Loss: 1.5127
# Episode 495 | Reward: 293.11 | Epsilon: 0.083 | Loss: 2.0257
# Episode 496 | Reward: 265.75 | Epsilon: 0.083 | Loss: 3.3871
# Episode 497 | Reward: 240.56 | Epsilon: 0.082 | Loss: 104.5515
# Episode 498 | Reward: 279.98 | Epsilon: 0.082 | Loss: 90.4258
# Episode 499 | Reward: -156.54 | Epsilon: 0.082 | Loss: 91.2265
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-9.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-9.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-9.mp4
# [EVAL] Episode 500 | Eval reward: -18.13 (video saved)

# %%
q_network.save("q_network.h5")
target_q_network.save("target_q_network.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def evaluate_policy(env, num_episodes=10, epsilon_eval=0.00):
    rewards = []
    for ep in range(num_episodes):
        state, info = env.reset()
        done = False
        total_reward = 0.0

        while not done:
            if np.random.rand() < epsilon_eval:
                action = env.action_space.sample()
            else:
                state_tensor = tf.convert_to_tensor(state[None, :], dtype=tf.float32)
                q_values = q_network(state_tensor)
                action = int(tf.argmax(q_values[0]).numpy())

            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            total_reward += reward
            state = next_state

        rewards.append(total_reward)
        print(f"Eval Episode {ep} | Reward: {total_reward:.2f}")

    print(f"\nAverage eval reward over {num_episodes} episodes: {np.mean(rewards):.2f}")
    return rewards
eval_rewards = evaluate_policy(eval_env, num_episodes=10, epsilon_eval=0.05)
# Out:
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-20.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-20.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-20.mp4
# Eval Episode 0 | Reward: 243.26
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-21.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-21.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-21.mp4
# Eval Episode 1 | Reward: -14.36
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-22.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-22.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-22.mp4
# Eval Episode 2 | Reward: 247.57
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-23.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-23.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-23.mp4
# Eval Episode 3 | Reward: 241.84
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-24.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-24.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-24.mp4
# Eval Episode 4 | Reward: 239.17
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-25.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-25.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-25.mp4
# Eval Episode 5 | Reward: 230.09
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-26.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-26.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-26.mp4
# Eval Episode 6 | Reward: 259.11
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-27.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-27.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-27.mp4
# Eval Episode 7 | Reward: 260.71
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-28.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-28.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-28.mp4
# Eval Episode 8 | Reward: 276.04
# MoviePy - Building video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-29.mp4.
# MoviePy - Writing video c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-29.mp4
# MoviePy - Done !
# MoviePy - video ready c:\Users\hp\Documents\tf_gpu\rl_rev\videos\dqn_lander-episode-29.mp4
# Eval Episode 9 | Reward: 265.91
#
# Average eval reward over 10 episodes: 224.93
